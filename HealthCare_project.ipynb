# %%
import pandas as pd
import numpy as np 
import datetime 
from time import strftime 
import matplotlib.pyplot as plt
# %matplotlib inline 

import seaborn as sns

# %%
HC = pd.read_csv('dataframe.csv')
HC
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
HC.shape
# Out:
# (55500, 15)

# %%
HC[HC['Test Results']=='Normal'].shape
# Out:
# (18517, 15)

# %%
HC[HC['Test Results']=='Inconclusive'].shape
# Out:
# (18356, 15)

# %%
HC[HC['Test Results']=='Abnormal'].shape
# Out:
# (18437, 15)

# %%
HC.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
# lets see random 5 records of patient
HC.sample(5)
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 46569      richARD mOORE   31  Female         B+            Asthma
# 33644  bRiTtAnY hAMILTON   32    Male        AB-            Cancer
# 46077        loRi meLton   55  Female        AB+      Hypertension
# 17254        brIAn elLIS   21    Male        AB-           Obesity
# 47598        JOhn MACIAs   21    Male        AB-         Arthritis
#
#       Date of Admission             Doctor                     Hospital  \
# 46569        2020-05-17  Melissa Velazquez                 Brown-Romero
# 33644        2021-01-12       Daniel James                   LLC Barton
# 46077        2022-07-26        Mark Massey        Taylor Buck and Kirk,
# 17254        2023-06-25     Brent Gonzalez  and Rodriguez, Dunn Edwards
# 47598        2021-08-22         Megan Webb               Banks-Petersen
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# ...

# %%
#CLEANING

# %%
HC[HC['Gender']=='Female'].shape
# Out:
# (27726, 15)

# %%
HC[HC['Billing Amount'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Name, Age, Gender, Blood Type, Medical Condition, Date of Admission, Doctor, Hospital, Insurance Provider, Billing Amount, Room Number, Admission Type, Discharge Date, Medication, Test Results]
# Index: []

# %%
Senior_Citizen=HC[HC['Age'] > 60]
Senior_Citizen
# Out:
#                    Name  Age  Gender Blood Type Medical Condition  \
# 1          LesLie TErRy   62    Male         A+           Obesity
# 2           DaNnY sMitH   76  Female         A-           Obesity
# 8       JASmINe aGuIlaR   82    Male        AB+            Asthma
# 10     mIchElLe daniELs   72    Male         O+            Cancer
# 12        connOR HANsEn   75  Female         A+          Diabetes
# ...                 ...  ...     ...        ...               ...
# 55487    mIsTy RICharDs   78  Female         O-      Hypertension
# 55489    ANdrEw AGUIlaR   69    Male         O-         Arthritis
# 55490  STepHAniE oliVer   82    Male         B-            Cancer
# 55494     JEssIcA WHiTe   67    Male         O+         Arthritis
# 55496        KYle pEREz   61  Female        AB-           Obesity
#
#       Date of Admission            Doctor                   Hospital  \
# 1            2019-08-20   Samantha Davies                    Kim Inc
# ...

# %%
HC[HC.duplicated()]
# Out:
#                      Name  Age  Gender Blood Type Medical Condition  \
# 50023        Samuel joYCe   56    Male         O+         Arthritis
# 50040    KIMBErly vasqueZ   26    Male         A-           Obesity
# 50055      SCoTT tHOrNton   55  Female         B-           Obesity
# 50070         wiLliam LEe   27  Female         O+         Arthritis
# 50078  chRistOPheR NoRrIs   38    Male        AB-         Arthritis
# ...                   ...  ...     ...        ...               ...
# 55461      connOR coMPTon   63    Male         A+            Asthma
# 55462       alYSsA mIlLER   35  Female         A-          Diabetes
# 55464        ChRIs huGHeS   35  Female        AB-           Obesity
# 55484     keNNEtH alvarez   80    Male         O+            Cancer
# 55491       lInDA grIFfin   47  Female         O+           Obesity
#
#       Date of Admission             Doctor                    Hospital  \
# 50023        2022-11-03     Krista Hartman              Thomas-Ballard
# ...

# %%
HC=HC.drop_duplicates()

HC.to_csv('updated_dataset.csv', index=False)
HC
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
HC[HC.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Name, Age, Gender, Blood Type, Medical Condition, Date of Admission, Doctor, Hospital, Insurance Provider, Billing Amount, Room Number, Admission Type, Discharge Date, Medication, Test Results]
# Index: []

# %%
HC.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
HC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 54966 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                54966 non-null  object
#  1   Age                 54966 non-null  int64
#  2   Gender              54966 non-null  object
#  3   Blood Type          54966 non-null  object
#  4   Medical Condition   54966 non-null  object
#  5   Date of Admission   54966 non-null  object
#  6   Doctor              54966 non-null  object
#  7   Hospital            54966 non-null  object
#  8   Insurance Provider  54966 non-null  object
#  9   Billing Amount      54966 non-null  float64
#  10  Room Number         54966 non-null  int64
#  11  Admission Type      54966 non-null  object
#  12  Discharge Date      54966 non-null  object
#  13  Medication          54966 non-null  object
#  14  Test Results        54966 non-null  object
# dtypes: float64(1), int64(2), object(12)
# ...

# %%
HC.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
# Assume 'Discharge Date' is the column with missing values

# %%
pd.to_datetime(HC['Discharge Date'])
# Out:
# 0       2024-02-02
# 1       2019-08-26
# 2       2022-10-07
# 3       2020-12-18
# 4       2022-10-09
#            ...
# 55495   2020-09-15
# 55496   2020-02-01
# 55497   2020-08-10
# 55498   2019-05-31
# 55499   2024-04-29
# Name: Discharge Date, Length: 54966, dtype: datetime64[ns]

# %%
# Convert date columns to datetime
HC['Date of Admission'] = pd.to_datetime(HC['Date of Admission'])
HC['Discharge Date'] = pd.to_datetime(HC['Discharge Date'], errors='coerce')
HC['Date of Admission']
HC['Discharge Date'])
# Out:
# 0       2024-02-02
# 1       2019-08-26
# 2       2022-10-07
# 3       2020-12-18
# 4       2022-10-09
#            ...
# 55495   2020-09-15
# 55496   2020-02-01
# 55497   2020-08-10
# 55498   2019-05-31
# 55499   2024-04-29
# Name: Discharge Date, Length: 54966, dtype: datetime64[ns]

# %%
# Identify rows with missing discharge dates
missing_discharge_dates = HC['Discharge Date'].isnull()
missing_discharge_dates
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 55495    False
# 55496    False
# 55497    False
# 55498    False
# 55499    False
# Name: Discharge Date, Length: 54966, dtype: bool

# %%
# Group by medical condition and calculate average length of stay
recovery_trends = HC.groupby('Medical Condition')['Length_of_Stay'].mean().reset_index()
recovery_trends
# Out:
#   Medical Condition  Length_of_Stay
# 0         Arthritis       15.504231
# 1            Asthma       15.677295
# 2            Cancer       15.501204
# 3          Diabetes       15.430664
# 4      Hypertension       15.436236
# 5           Obesity       15.447627

# %%
recovery_trends = recovery_trends.sort_values(by='Length_of_Stay')
recovery_trends
# Out:
#   Medical Condition  Length_of_Stay
# 3          Diabetes       15.430664
# 4      Hypertension       15.436236
# 5           Obesity       15.447627
# 2            Cancer       15.501204
# 0         Arthritis       15.504231
# 1            Asthma       15.677295

# %%
# Plot patient recovery trends
plt.figure(figsize=(10,6))
plt.bar(recovery_trends['Medical Condition'], recovery_trends['Length_of_Stay'])
plt.xlabel('Medical Condition')
plt.ylabel('Average Length of Stay')
plt.title('Patient Recovery Trends')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

print(recovery_trends)
# Out:
#   Medical Condition  Length_of_Stay
# 3          Diabetes       15.430664
# 4      Hypertension       15.436236
# 5           Obesity       15.447627
# 2            Cancer       15.501204
# 0         Arthritis       15.504231
# 1            Asthma       15.677295

# %%
# Create age groups
HC['Age_Group'] = pd.cut(HC['Age'], bins=[0, 20, 60, np.inf], labels=['Below 20', '21-60', 'Above 60'], include_lowest=True, right=False)
HC['Age_Group']
# Out:
# 0           21-60
# 1        Above 60
# 2        Above 60
# 3           21-60
# 4           21-60
#            ...
# 55495       21-60
# 55496    Above 60
# 55497       21-60
# 55498       21-60
# 55499       21-60
# Name: Age_Group, Length: 54966, dtype: category
# Categories (3, object): ['Below 20' < '21-60' < 'Above 60']

# %%
# Group by age group and medical condition, calculate average length of stay
recovery_trends_below_20 = HC[HC['Age_Group'] == 'Below 20'].groupby('Medical Condition')['Length_of_Stay'].mean().reset_index().sort_values(by='Length_of_Stay', ascending=False).head(10)
recovery_trends_21_60 = HC[HC['Age_Group'] == '21-60'].groupby('Medical Condition')['Length_of_Stay'].mean().reset_index().sort_values(by='Length_of_Stay', ascending=False).head(10)
recovery_trends_above_60 = HC[HC['Age_Group'] == 'Above 60'].groupby('Medical Condition')['Length_of_Stay'].mean().reset_index().sort_values(by='Length_of_Stay', ascending=False).head(10)

recovery_trends_below_20

recovery_trends_21_60

recovery_trends_above_60
# Out:
#   Medical Condition  Length_of_Stay
# 2            Cancer       15.683219
# 5           Obesity       15.643968
# 1            Asthma       15.630769
# 0         Arthritis       15.610968
# 3          Diabetes       15.496882
# 4      Hypertension       15.395904

# %%
# Plot patient recovery trends
fig, axs = plt.subplots(3, figsize=(10, 15))
axs[0].bar(recovery_trends_below_20['Medical Condition'], recovery_trends_below_20['Length_of_Stay'])
axs[0].set_title('Patient Recovery Trends by Medical Condition (Below 20)')
axs[0].set_xlabel('Medical Condition')
axs[0].set_ylabel('Average Length of Stay')
axs[0].tick_params(axis='x', rotation=90)

axs[1].bar(recovery_trends_21_60['Medical Condition'], recovery_trends_21_60['Length_of_Stay'])
axs[1].set_title('Patient Recovery Trends by Medical Condition (21-60)')
axs[1].set_xlabel('Medical Condition')
axs[1].set_ylabel('Average Length of Stay')
axs[1].tick_params(axis='x', rotation=90)

axs[2].bar(recovery_trends_above_60['Medical Condition'], recovery_trends_above_60['Length_of_Stay'])
axs[2].set_title('Patient Recovery Trends by Medical Condition (Above 60)')
axs[2].set_xlabel('Medical Condition')
axs[2].set_ylabel('Average Length of Stay')
axs[2].tick_params(axis='x', rotation=90)

plt.tight_layout()
plt.show()

print(recovery_trends_below_20)
print(recovery_trends_21_60)
print(recovery_trends_above_60)
# Out:
#   Medical Condition  Length_of_Stay
# 4      Hypertension       15.938628
# 3          Diabetes       15.844444
# 1            Asthma       15.684783
# 0         Arthritis       15.415541
# 2            Cancer       15.120567
# 5           Obesity       14.695652
#   Medical Condition  Length_of_Stay
# 1            Asthma       15.707666
# 0         Arthritis       15.440706
# 4      Hypertension       15.436730
# 2            Cancer       15.402129
# 3          Diabetes       15.366925
# 5           Obesity       15.363170
#   Medical Condition  Length_of_Stay
# 2            Cancer       15.683219
# 5           Obesity       15.643968
# 1            Asthma       15.630769
# 0         Arthritis       15.610968
# 3          Diabetes       15.496882
# 4      Hypertension       15.395904

# %%
# Group by doctor and calculate average length of stay
doctor_performance = HC.groupby('Doctor')['Length_of_Stay'].mean().reset_index().sort_values(by='Length_of_Stay')
doctor_performance
# Out:
#                   Doctor  Length_of_Stay
# 28987  Mr. Martin Dawson             1.0
# 34648     Sean Hendricks             1.0
# 15775      James Hunt MD             1.0
# 38958    Tyler Smith DVM             1.0
# 26795        Megan Hicks             1.0
# ...                  ...             ...
# 9938        David Guzman            30.0
# 4641      Brandon Valdez            30.0
# 23798      Lauren Dalton            30.0
# 33589     Sabrina Guzman            30.0
# 24714         Lisa Weiss            30.0
#
# [40341 rows x 2 columns]

# %%
# Rank the doctors based on their average length of stay
doctor_performance = doctor_performance.sort_values(by='Length_of_Stay')
doctor_performance
# Out:
#                   Doctor  Length_of_Stay
# 28987  Mr. Martin Dawson             1.0
# 9781          Dave Jones             1.0
# 3925      Benjamin Craig             1.0
# 14346     Gregory Hughes             1.0
# 29531     Natalie Hanson             1.0
# ...                  ...             ...
# 34731       Selena Hardy            30.0
# 2100        Andrew Doyle            30.0
# 13749  Gabriella Elliott            30.0
# 13131        Erik Howard            30.0
# 24714         Lisa Weiss            30.0
#
# [40341 rows x 2 columns]

# %%
# Get the top 10 performing doctors
top_doctors = doctor_performance.nsmallest(10, 'Length_of_Stay')
top_doctors
# Out:
#                    Doctor  Length_of_Stay
# 28987   Mr. Martin Dawson             1.0
# 9781           Dave Jones             1.0
# 3925       Benjamin Craig             1.0
# 14346      Gregory Hughes             1.0
# 29531      Natalie Hanson             1.0
# 34081       Sara Mcdonald             1.0
# 23239  Kristopher Salazar             1.0
# 420          Alan Gilbert             1.0
# 189            Adam Burns             1.0
# 39354    Victoria Johnson             1.0

# %%
# Get the bottom 10 performing doctors
bottom_doctors = doctor_performance.nlargest(10, 'Length_of_Stay')
bottom_doctors
# Out:
#                  Doctor  Length_of_Stay
# 30418  Pamela Conway MD            30.0
# 8239          Cody Shaw            30.0
# 30461     Pamela Jordan            30.0
# 19755   Joseph Mccarthy            30.0
# 6567   Catherine Torres            30.0
# 21707        Kayla Wood            30.0
# 8387        Connie Kane            30.0
# 19661      Joseph Dixon            30.0
# 6538    Catherine Nolan            30.0
# 19656     Joseph Curtis            30.0

# %%
# Plot the top-performing doctors
plt.figure(figsize=(10,6))
plt.bar(top_doctors['Doctor'], top_doctors['Length_of_Stay'])
plt.xlabel('Doctor')
plt.ylabel('Average Length of Stay')
plt.title('Top-Performing Doctors')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()


print(top_doctors)
# Out:
#                    Doctor  Length_of_Stay
# 28987   Mr. Martin Dawson             1.0
# 9781           Dave Jones             1.0
# 3925       Benjamin Craig             1.0
# 14346      Gregory Hughes             1.0
# 29531      Natalie Hanson             1.0
# 34081       Sara Mcdonald             1.0
# 23239  Kristopher Salazar             1.0
# 420          Alan Gilbert             1.0
# 189            Adam Burns             1.0
# 39354    Victoria Johnson             1.0

# %%
# Plot the bottom-performing doctors
plt.figure(figsize=(10,6))
plt.bar(bottom_doctors['Doctor'], bottom_doctors['Length_of_Stay'])
plt.xlabel('Doctor')
plt.ylabel('Average Length of Stay')
plt.title('Bottom-Performing Doctors')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

print(bottom_doctors)
# Out:
#                  Doctor  Length_of_Stay
# 30418  Pamela Conway MD            30.0
# 8239          Cody Shaw            30.0
# 30461     Pamela Jordan            30.0
# 19755   Joseph Mccarthy            30.0
# 6567   Catherine Torres            30.0
# 21707        Kayla Wood            30.0
# 8387        Connie Kane            30.0
# 19661      Joseph Dixon            30.0
# 6538    Catherine Nolan            30.0
# 19656     Joseph Curtis            30.0
